# %% [markdown]
# **Excercise 3.1**

# %%
A={'a','bb','c'}
B={'A','bb','d',42}

# %%
set.union(A,B)
# Out:
# {42, 'A', 'a', 'bb', 'c', 'd'}

# %%
set.intersection(A,B)
# Out:
# {'bb'}

# %%
set.difference(A,B)
# Out:
# {'a', 'c'}

# %%
set.difference(B,A)
# Out:
# {42, 'A', 'd'}

# %% [markdown]
# **Excercise 3.3**

# %%
#Given x=1+0.2n and 1<x<=2.2
n=1; x=1; count=0
while x<2.2:
  x=1+0.2*n
  count=count+1
  n=n+1
import numpy as np
#Since for n=1, x=1.2
np.linspace(1.2, 2.2, count)
# Out:
# array([1.2, 1.4, 1.6, 1.8, 2. , 2.2])
